# %%
import torch
from torch import nn
from torchsummary import summary
import matplotlib.pyplot as plt
import json
import time
import models
import utils

# %%
idx = 2

options = ["", "1", "2"]
option = options[idx]

with open('configuration.json') as file:
    configuration = json.load(file)

IMG_HEIGHT = configuration["image"]["heigth"]
IMG_WIDTH = configuration["image"]["width"]
IMG_CHANNELS = configuration["image"]["channels"]

if option == options[0]:
    DATA_PATH = configuration["path"]["data_z"]
else:
    DATA_PATH = configuration["path"]["data_f"]

DATA_PATH = "dataNuInsSeg_alter"

device = utils.select_device()
model = models.Auto().to(device)
summary(model, input_size=(IMG_CHANNELS, IMG_HEIGHT, IMG_WIDTH))
# Out:
# GPU disponible
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 256, 256]             448
#               ReLU-2         [-1, 16, 256, 256]               0
#             Conv2d-3         [-1, 16, 256, 256]           2,320
#               ReLU-4         [-1, 16, 256, 256]               0
#         DoubleConv-5         [-1, 16, 256, 256]               0
#          MaxPool2d-6         [-1, 16, 128, 128]               0
#             Conv2d-7         [-1, 32, 128, 128]           4,640
#               ReLU-8         [-1, 32, 128, 128]               0
#             Conv2d-9         [-1, 32, 128, 128]           9,248
#              ReLU-10         [-1, 32, 128, 128]               0
#        DoubleConv-11         [-1, 32, 128, 128]               0
#         MaxPool2d-12           [-1, 32, 64, 64]               0
#            Conv2d-13           [-1, 64, 64, 64]          18,496
#              ReLU-14           [-1, 64, 64, 64]               0
#            Conv2d-15           [-1, 64, 64, 64]          36,928
#              ReLU-16           [-1, 64, 64, 64]               0
#        DoubleConv-17           [-1, 64, 64, 64]               0
#         MaxPool2d-18           [-1, 64, 32, 32]               0
#            Conv2d-19          [-1, 128, 32, 32]          73,856
#              ReLU-20          [-1, 128, 32, 32]               0
#            Conv2d-21          [-1, 128, 32, 32]         147,584
#              ReLU-22          [-1, 128, 32, 32]               0
#        DoubleConv-23          [-1, 128, 32, 32]               0
#         MaxPool2d-24          [-1, 128, 16, 16]               0
#            Conv2d-25          [-1, 256, 16, 16]         295,168
#              ReLU-26          [-1, 256, 16, 16]               0
#            Conv2d-27          [-1, 256, 16, 16]         590,080
#              ReLU-28          [-1, 256, 16, 16]               0
#        DoubleConv-29          [-1, 256, 16, 16]               0
#   ConvTranspose2d-30          [-1, 128, 32, 32]         131,200
#            Conv2d-31          [-1, 128, 32, 32]         147,584
#              ReLU-32          [-1, 128, 32, 32]               0
#            Conv2d-33          [-1, 128, 32, 32]         147,584
#              ReLU-34          [-1, 128, 32, 32]               0
#        DoubleConv-35          [-1, 128, 32, 32]               0
#   ConvTranspose2d-36           [-1, 64, 64, 64]          32,832
#            Conv2d-37           [-1, 64, 64, 64]          36,928
#              ReLU-38           [-1, 64, 64, 64]               0
#            Conv2d-39           [-1, 64, 64, 64]          36,928
#              ReLU-40           [-1, 64, 64, 64]               0
#        DoubleConv-41           [-1, 64, 64, 64]               0
#   ConvTranspose2d-42         [-1, 32, 128, 128]           8,224
#            Conv2d-43         [-1, 32, 128, 128]           9,248
#              ReLU-44         [-1, 32, 128, 128]               0
#            Conv2d-45         [-1, 32, 128, 128]           9,248
#              ReLU-46         [-1, 32, 128, 128]               0
#        DoubleConv-47         [-1, 32, 128, 128]               0
#   ConvTranspose2d-48         [-1, 16, 256, 256]           2,064
#            Conv2d-49         [-1, 16, 256, 256]           2,320
#              ReLU-50         [-1, 16, 256, 256]               0
#            Conv2d-51         [-1, 16, 256, 256]           2,320
#              ReLU-52         [-1, 16, 256, 256]               0
#        DoubleConv-53         [-1, 16, 256, 256]               0
#            Conv2d-54          [-1, 3, 256, 256]              51
# ================================================================
# Total params: 1,745,299
# Trainable params: 1,745,299
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 172.75
# Params size (MB): 6.66
# Estimated Total Size (MB): 180.16
# ----------------------------------------------------------------

# %%
X = utils.load_images(DATA_PATH=DATA_PATH, getMask = False)
# Out:
# imagenes
# 100%|██████████| 2660/2660 [00:05<00:00, 466.49it/s]

# %%
train_loader, validation_loader, test_loader = utils.create_loader(X, X, 64)

print(len(train_loader))
print(len(validation_loader))
print(len(test_loader))
# Out:
# 25
# 9
# 9

# %%
model = models.Auto()
model.load_state_dict(torch.load(f"./models/auto{option}.pth"))
model.to(device)

# Definimos los hiperparámetros
n_epochs = 200
lr=0.0001
patience = 5 # (vamos a usar early stopping, así que definimos un valor de paciencia)

# Definimos la función de pérdida (error cuadrático medio)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
# Out:
# C:\Users\mauri\AppData\Local\Temp\ipykernel_23904\3757882300.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"./models/auto{option}.pth"))

# %%
# Definimos las funciones de entrenamiento y evaluación

def train(model,loader):
    total_loss = 0.0
    for data in loader:
        model.train()
        inputs, targets = data
        inputs = inputs.to(device)
        targets = targets.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * inputs.size(0)
    total_loss/= len(loader.dataset)
    return total_loss 


def test(model,loader):
    model.eval()
    total_loss = 0.0
    for data in loader:
        inputs, targets = data
        inputs = inputs.to(device)
        targets = targets.to(device)
        with torch.no_grad():
            outputs = model(inputs)
            loss = criterion(outputs, targets)
        total_loss += loss.item() * inputs.size(0)
    total_loss/= len(loader.dataset)
    return total_loss

# %%
# Entrenamos con early stopping

# Valores iniciales para el early stopping
best_val_loss = 10000.0
best_train_loss = 10000.0
j = 0
epoch = 0
selected_model_state_dict = model.state_dict()

start = time.time()
i_time = time.time()

while ((epoch < n_epochs) and (j < patience)):
    train_loss = train(model, train_loader)
    validation_loss = test(model, validation_loader)

    if epoch%1 == 0:
        i_elapsed = time.time()-i_time
        
        print('Epoca: {}/{}.............'.format(epoch, n_epochs), end=' ')
        print("Train loss: {:.4f}".format(train_loss), ", Validation loss: {:.4f}".format(validation_loss), ", best: {:.4f}".format(min(best_val_loss, validation_loss)), f", Elapsed: {int((i_elapsed // 60) % 60)} minutos, {int(i_elapsed % 60)} segundos")
        i_time = time.time()
        
    if (validation_loss <= best_val_loss):
        best_epoch = epoch
        best_train_loss = train_loss
        best_val_loss = validation_loss
        selected_model_state_dict = model.state_dict()
        j = 0
    else:
        j += 1

    epoch += 1
        
print('La mejor Epoca fue {:03d}, Train loss: {:.4f}, Validation loss: {:.4f}'.format(
              best_epoch, best_train_loss, best_val_loss))
end = time.time()
elapsed = end-start
print(f"Tiempo de ejecución: {int(elapsed // 3600)} horas, {int((elapsed // 60) % 60)} minutos, {int(elapsed % 60)} segundos")

# Nos quedamos con el modelo con mejor valor de validación  
model.load_state_dict(selected_model_state_dict)
# Out:
# Epoca: 0/200............. Train loss: 524.3008 , Validation loss: 279.0748 , best: 279.0748 , Elapsed: 0 minutos, 12 segundos
# Epoca: 1/200............. Train loss: 284.0814 , Validation loss: 274.3412 , best: 274.3412 , Elapsed: 0 minutos, 12 segundos
# Epoca: 2/200............. Train loss: 264.5331 , Validation loss: 266.9692 , best: 266.9692 , Elapsed: 0 minutos, 12 segundos
# Epoca: 47/200............. Train loss: 236.5465 , Validation loss: 238.1567 , best: 238.1567 , Elapsed: 0 minutos, 12 segundos
# Epoca: 48/200............. Train loss: 233.7243 , Validation loss: 238.4991 , best: 238.1567 , Elapsed: 0 minutos, 12 segundos
# Epoca: 49/200............. Train loss: 236.7971 , Validation loss: 237.8993 , best: 237.8993 , Elapsed: 0 minutos, 12 segundos
# Epoca: 50/200............. Train loss: 232.8442 , Validation loss: 239.3349 , best: 237.8993 , Elapsed: 0 minutos, 12 segundos
# Epoca: 51/200............. Train loss: 237.8358 , Validation loss: 249.5491 , best: 237.8993 , Elapsed: 0 minutos, 12 segundos
# Epoca: 52/200............. Train loss: 235.2432 , Validation loss: 236.5653 , best: 236.5653 , Elapsed: 0 minutos, 12 segundos
# Epoca: 53/200............. Train loss: 233.7357 , Validation loss: 238.1616 , best: 236.5653 , Elapsed: 0 minutos, 12 segundos
# Epoca: 54/200............. Train loss: 233.4188 , Validation loss: 237.1634 , best: 236.5653 , Elapsed: 0 minutos, 12 segundos
# Epoca: 55/200............. Train loss: 232.2004 , Validation loss: 235.2757 , best: 235.2757 , Elapsed: 0 minutos, 12 segundos
# Epoca: 56/200............. Train loss: 233.2503 , Validation loss: 241.6027 , best: 235.2757 , Elapsed: 0 minutos, 12 segundos
# Epoca: 57/200............. Train loss: 233.3069 , Validation loss: 242.7838 , best: 235.2757 , Elapsed: 0 minutos, 12 segundos
# Epoca: 58/200............. Train loss: 233.6654 , Validation loss: 237.0542 , best: 235.2757 , Elapsed: 0 minutos, 11 segundos
# Epoca: 59/200............. Train loss: 232.0417 , Validation loss: 240.3967 , best: 235.2757 , Elapsed: 0 minutos, 11 segundos
# Epoca: 60/200............. Train loss: 232.1241 , Validation loss: 239.0938 , best: 235.2757 , Elapsed: 0 minutos, 12 segundos
# La mejor Epoca fue 055, Train loss: 232.2004, Validation loss: 235.2757
# Tiempo de ejecución: 0 horas, 12 minutos, 38 segundos
# <All keys matched successfully>

# %%
model.load_state_dict(selected_model_state_dict)
print(test(model, validation_loader))
print(test(model, train_loader))
print(test(model, test_loader))
# Out:
# 239.09375631002555
# 234.849116734096
# 236.86241436721687

# %%
torch.save(model.state_dict(), f"./models/auto{option}.pth")

# %%
model.load_state_dict(torch.load(f"./models/auto{option}.pth"))
# Out:
# C:\Users\mauri\AppData\Local\Temp\ipykernel_23904\3723940364.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"./models/auto{option}.pth"))
# <All keys matched successfully>

# %%
model.eval()
idx = 176
input = torch.tensor(X[idx], dtype=torch.float32).unsqueeze(0).to(device)
with torch.no_grad():
    output = model(input)

# %%
input_image = input.squeeze().permute(1, 2, 0).cpu().numpy()/255
output_image = output.squeeze().permute(1, 2, 0).cpu().numpy()/255

fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].imshow(input_image)
axs[0].set_title("Input")

axs[1].imshow(output_image)  # Si tienes ground truth
axs[1].set_title("Output")

for ax in axs:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
a, b = utils.test_similarity(model, zip(X, X))
# Out:
# 2660it [00:09, 278.14it/s]
# Dice: 0.9999749902704237
# Jaccard: 0.9999500551916902
