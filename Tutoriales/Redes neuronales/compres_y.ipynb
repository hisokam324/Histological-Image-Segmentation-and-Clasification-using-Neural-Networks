# %% [markdown]
# Aca solo se quiere acomodar los datos

# %%
import os
import numpy as np
from skimage.io import imread, imshow, imsave
from skimage import img_as_ubyte
from skimage.transform import resize, rotate
from tqdm import tqdm
import json

# %%
with open('configuration.json') as file:
    configuration = json.load(file)

TRAIN_PATH = f"{configuration["path"]["data_bowl"]}/{configuration["path"]["train"]}/"
TEST_PATH = f"{configuration["path"]["data_bowl"]}/{configuration["path"]["test"]}/"
SAVE_UNET = f"{configuration["path"]["data_y"]}/"
SAVE_AUTO = f"{configuration["path"]["data_z"]}/"
IMG_HEIGHT = configuration["image"]["heigth"]
IMG_WIDTH = configuration["image"]["width"]
IMG_CHANNELS = configuration["image"]["channels"]

# %%
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
lengths = []

for n, id in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id
    img = imread(path + "/images/" + id + ".png")[:,:,:IMG_CHANNELS]
    incorrect_size = img.shape[:2]!=(IMG_HEIGHT, IMG_WIDTH)
    if incorrect_size:
        img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + "/masks"))[2]:
        aux_mask = imread(path + "/masks/" + mask_file)
        if incorrect_size:
            aux_mask  = np.expand_dims(resize(aux_mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True), axis=-1)
        else:
            aux_mask = np.expand_dims(aux_mask, axis=-1)
        mask = np.maximum(mask, aux_mask)
    Y_train[n] = mask

X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
for n, id in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id
    print(path + "/images/" + id + ".png")
    img = imread(path + "/images/" + id + ".png")[:,:,:IMG_CHANNELS]
    incorrect_size = img.shape[:2]!=(IMG_HEIGHT, IMG_WIDTH)
    if incorrect_size:
        img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img
# Out:
#   0%|          | 0/670 [00:00<?, ?it/s]
# 100%|██████████| 670/670 [03:04<00:00,  3.63it/s]
#   0%|          | 0/670 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 28
#      26 for n, id in tqdm(enumerate(train_ids), total=len(train_ids)):
#      27     path = TEST_PATH + id
# ---> 28     img = imread(path + "/images/" + id + ".png")[:,:,:IMG_CHANNELS]
#      29     incorrect_size = img.shape[:2]!=(IMG_HEIGHT, IMG_WIDTH)
#      30     if incorrect_size:
#
# File c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328, in deprecate_parameter.__call__.<locals>.fixed_func(*args, **kwargs)
#     324     elif self.new_name is not None:
#     325         # Assign old value to new one
#     326         kwargs[self.new_name] = deprecated_value
# --> 328 return func(*args, **kwargs)
#
# File c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\io\_io.py:82, in imread(fname, as_gray, plugin, **plugin_args)
#      79         plugin = 'tifffile'
#      81 with file_or_url_context(fname) as fname, _hide_plugin_deprecation_warnings():
# ---> 82     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      84 if not hasattr(img, 'ndim'):
#      85     return img
#
# File c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:538, in deprecate_func.__call__.<locals>.wrapped(*args, **kwargs)
#     536 stacklevel = 1 + self.get_stack_length(func) - stack_rank
#     537 warnings.warn(message, category=FutureWarning, stacklevel=stacklevel)
# --> 538 return func(*args, **kwargs)
#
# File c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\io\manage_plugins.py:254, in call_plugin(kind, *args, **kwargs)
#     251     except IndexError:
#     252         raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
# --> 254 return func(*args, **kwargs)
#
# File c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\io\_plugins\imageio_plugin.py:11, in imread(*args, **kwargs)
#       9 @wraps(imageio_imread)
#      10 def imread(*args, **kwargs):
# ---> 11     out = np.asarray(imageio_imread(*args, **kwargs))
#      12     if not out.flags['WRITEABLE']:
#      13         out = out.copy()
#
# File c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\imageio\v3.py:53, in imread(uri, index, plugin, extension, format_hint, **kwargs)
#      50 if index is not None:
#      51     call_kwargs["index"] = index
# ---> 53 with imopen(uri, "r", **plugin_kwargs) as img_file:
#      54     return np.asarray(img_file.read(**call_kwargs))
#
# File c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\imageio\core\imopen.py:113, in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111     request.format_hint = format_hint
#     112 else:
# --> 113     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     115 source = "<bytes>" if isinstance(uri, bytes) else uri
#     117 # fast-path based on plugin
#     118 # (except in legacy mode)
#
# File c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\imageio\core\request.py:249, in Request.__init__(self, uri, mode, extension, format_hint, **kwargs)
#     246     raise ValueError(f"Invalid Request.Mode: {mode}")
#     248 # Parse what was given
# --> 249 self._parse_uri(uri)
#     251 # Set extension
#     252 if extension is not None:
#
# File c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\imageio\core\request.py:409, in Request._parse_uri(self, uri)
#     406 if is_read_request:
#     407     # Reading: check that the file exists (but is allowed a dir)
#     408     if not os.path.exists(fn):
# --> 409         raise FileNotFoundError("No such file: '%s'" % fn)
#     410 else:
#     411     # Writing: check that the directory to write to does exist
#     412     dn = os.path.dirname(fn)
#
# FileNotFoundError: No such file: 'c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\data-science-bowl-2018\stage1_test\00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552\images\00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552.png'

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 670
# 65

# %%
length = len(X_train)
for n in tqdm(range(len(X_train)), total=len(X_train)):
    imsave(SAVE_AUTO+"image/"+str(n)+".png", X_train[n])
    imsave(SAVE_AUTO+"image/"+str(n+length)+".png", img_as_ubyte(rotate(X_train[n], 90)))
    imsave(SAVE_AUTO+"image/"+str(n+2*length)+".png", img_as_ubyte(rotate(X_train[n], 180)))
    imsave(SAVE_AUTO+"image/"+str(n+3*length)+".png", img_as_ubyte(rotate(X_train[n], 270)))
    imsave(SAVE_UNET+"image/"+str(n)+".png", X_train[n])
    imsave(SAVE_UNET+"image/"+str(n+length)+".png", img_as_ubyte(rotate(X_train[n], 90)))
    imsave(SAVE_UNET+"image/"+str(n+2*length)+".png", img_as_ubyte(rotate(X_train[n], 180)))
    imsave(SAVE_UNET+"image/"+str(n+3*length)+".png", img_as_ubyte(rotate(X_train[n], 270)))
    imsave(SAVE_UNET + "mask/" + str(n) + ".bmp", np.squeeze(Y_train[n]).astype(np.uint8) * 255)
    imsave(SAVE_UNET + "mask/" + str(n+length) + ".bmp", np.squeeze(img_as_ubyte(rotate(Y_train[n], 90)).astype(np.uint8) * 255))
    imsave(SAVE_UNET + "mask/" + str(n+2*length) + ".bmp", np.squeeze(img_as_ubyte(rotate(Y_train[n], 180)).astype(np.uint8) * 255))
    imsave(SAVE_UNET + "mask/" + str(n+3*length) + ".bmp", np.squeeze(img_as_ubyte(rotate(Y_train[n], 270)).astype(np.uint8) * 255))

offset = length*4
length = len(X_test)
for n in tqdm(range(len(X_test)), total=len(X_test)):
    imsave(SAVE_AUTO+"image/"+str(offset+n)+".png", X_test[n])
    imsave(SAVE_AUTO+"image/"+str(offset+n+length)+".png", img_as_ubyte(rotate(X_test[n], 90)))
    imsave(SAVE_AUTO+"image/"+str(offset+n+2*length)+".png", img_as_ubyte(rotate(X_test[n], 180)))
    imsave(SAVE_AUTO+"image/"+str(offset+n+3*length)+".png", img_as_ubyte(rotate(X_test[n], 270)))
# Out:
#   0%|          | 0/670 [00:00<?, ?it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/670.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1340.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2010.bmp is a low contrast image
#   return func(*args, **kwargs)
#   0%|          | 1/670 [00:00<01:40,  6.69it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/671.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1341.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2011.bmp is a low contrast image
#   return func(*args, **kwargs)
#   0%|          | 2/670 [00:00<01:36,  6.96it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/672.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1342.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2012.bmp is a low contrast image
#   return func(*args, **kwargs)
#   0%|          | 3/670 [00:00<01:28,  7.54it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/673.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1343.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2013.bmp is a low contrast image
#   return func(*args, **kwargs)
#   1%|          | 4/670 [00:00<01:27,  7.61it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/674.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1344.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2014.bmp is a low contrast image
#   return func(*args, **kwargs)
#   1%|          | 5/670 [00:00<01:40,  6.64it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/675.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1345.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2015.bmp is a low contrast image
#   return func(*args, **kwargs)
#   1%|          | 6/670 [00:00<01:41,  6.52it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/676.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1346.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2016.bmp is a low contrast image
#   return func(*args, **kwargs)
#   1%|          | 7/670 [00:01<01:36,  6.89it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/677.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1347.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2017.bmp is a low contrast image
#   return func(*args, **kwargs)
#   1%|          | 8/670 [00:01<01:30,  7.35it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/678.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1348.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2018.bmp is a low contrast image
#   return func(*args, **kwargs)
#   1%|▏         | 9/670 [00:01<01:30,  7.29it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/679.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1349.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2019.bmp is a low contrast image
#   return func(*args, **kwargs)
#   1%|▏         | 10/670 [00:01<01:28,  7.43it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/680.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1350.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2020.bmp is a low contrast image
#   return func(*args, **kwargs)
#   2%|▏         | 11/670 [00:01<01:30,  7.27it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/681.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1351.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2021.bmp is a low contrast image
#   return func(*args, **kwargs)
#   2%|▏         | 12/670 [00:01<01:28,  7.43it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/682.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1352.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2022.bmp is a low contrast image
#   return func(*args, **kwargs)
#   2%|▏         | 13/670 [00:01<01:26,  7.59it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/683.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1353.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2023.bmp is a low contrast image
#   return func(*args, **kwargs)
#   2%|▏         | 14/670 [00:01<01:30,  7.22it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/684.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1354.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2024.bmp is a low contrast image
#   return func(*args, **kwargs)
#   2%|▏         | 15/670 [00:02<01:28,  7.38it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/685.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1355.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2025.bmp is a low contrast image
#   return func(*args, **kwargs)
#   2%|▏         | 16/670 [00:02<01:27,  7.47it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/686.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1356.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2026.bmp is a low contrast image
#   return func(*args, **kwargs)
#   3%|▎         | 17/670 [00:02<01:25,  7.64it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/687.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1357.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2027.bmp is a low contrast image
#   return func(*args, **kwargs)
#   3%|▎         | 18/670 [00:02<01:23,  7.79it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/688.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1358.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2028.bmp is a low contrast image
#   return func(*args, **kwargs)
#   3%|▎         | 19/670 [00:02<01:23,  7.79it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/19.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/689.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/1359.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2029.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/19.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/689.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/1359.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/2029.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/19.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/689.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1359.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2029.bmp is a low contrast image
#   return func(*args, **kwargs)
#   3%|▎         | 20/670 [00:02<01:24,  7.68it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/690.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1360.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2030.bmp is a low contrast image
#   return func(*args, **kwargs)
#   3%|▎         | 21/670 [00:02<01:25,  7.57it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/691.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1361.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2031.bmp is a low contrast image
#   return func(*args, **kwargs)
#   3%|▎         | 22/670 [00:02<01:25,  7.57it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/692.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1362.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2032.bmp is a low contrast image
#   return func(*args, **kwargs)
#   3%|▎         | 23/670 [00:03<01:20,  8.04it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/693.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1363.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2033.bmp is a low contrast image
#   return func(*args, **kwargs)
#   4%|▎         | 24/670 [00:03<01:20,  8.04it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/694.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1364.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2034.bmp is a low contrast image
#   return func(*args, **kwargs)
#   4%|▎         | 25/670 [00:03<01:22,  7.80it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/695.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1365.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2035.bmp is a low contrast image
#   return func(*args, **kwargs)
#   4%|▍         | 26/670 [00:03<01:22,  7.82it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/696.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1366.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2036.bmp is a low contrast image
#   return func(*args, **kwargs)
#   4%|▍         | 27/670 [00:03<01:22,  7.84it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/697.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1367.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2037.bmp is a low contrast image
#   return func(*args, **kwargs)
#   4%|▍         | 28/670 [00:03<01:26,  7.43it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/698.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1368.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2038.bmp is a low contrast image
#   return func(*args, **kwargs)
#   4%|▍         | 29/670 [00:03<01:27,  7.31it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/29.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/699.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/1369.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2039.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/29.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/699.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/1369.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/2039.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/699.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1369.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2039.bmp is a low contrast image
#   return func(*args, **kwargs)
#   4%|▍         | 30/670 [00:04<01:24,  7.61it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/700.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1370.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2040.bmp is a low contrast image
#   return func(*args, **kwargs)
#   5%|▍         | 31/670 [00:04<01:22,  7.75it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/701.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1371.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2041.bmp is a low contrast image
#   return func(*args, **kwargs)
#   5%|▍         | 32/670 [00:04<01:26,  7.40it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/702.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1372.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2042.bmp is a low contrast image
#   return func(*args, **kwargs)
#   5%|▍         | 33/670 [00:04<01:31,  6.99it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/703.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1373.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2043.bmp is a low contrast image
#   return func(*args, **kwargs)
#   5%|▌         | 34/670 [00:04<01:30,  7.06it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/704.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1374.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2044.bmp is a low contrast image
#   return func(*args, **kwargs)
#   5%|▌         | 35/670 [00:04<01:29,  7.10it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/705.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1375.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2045.bmp is a low contrast image
#   return func(*args, **kwargs)
#   5%|▌         | 36/670 [00:04<01:30,  7.02it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/36.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/706.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/1376.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2046.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/36.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/706.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/1376.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/2046.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/706.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1376.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2046.bmp is a low contrast image
#   return func(*args, **kwargs)
#   6%|▌         | 37/670 [00:05<01:29,  7.06it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/707.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1377.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2047.bmp is a low contrast image
#   return func(*args, **kwargs)
#   6%|▌         | 38/670 [00:05<01:31,  6.93it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/708.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1378.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2048.bmp is a low contrast image
#   return func(*args, **kwargs)
#   6%|▌         | 39/670 [00:05<01:27,  7.21it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/709.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1379.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2049.bmp is a low contrast image
#   return func(*args, **kwargs)
#   6%|▌         | 40/670 [00:05<01:31,  6.88it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/710.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1380.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2050.bmp is a low contrast image
#   return func(*args, **kwargs)
#   6%|▌         | 41/670 [00:05<01:28,  7.12it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/711.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1381.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2051.bmp is a low contrast image
#   return func(*args, **kwargs)
#   6%|▋         | 42/670 [00:05<01:25,  7.37it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/712.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1382.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2052.bmp is a low contrast image
#   return func(*args, **kwargs)
#   6%|▋         | 43/670 [00:05<01:24,  7.43it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/713.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1383.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2053.bmp is a low contrast image
#   return func(*args, **kwargs)
#   7%|▋         | 44/670 [00:05<01:24,  7.39it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/714.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1384.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2054.bmp is a low contrast image
#   return func(*args, **kwargs)
#   7%|▋         | 45/670 [00:06<01:24,  7.42it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/715.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1385.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2055.bmp is a low contrast image
#   return func(*args, **kwargs)
#   7%|▋         | 46/670 [00:06<01:21,  7.69it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/716.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1386.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2056.bmp is a low contrast image
#   return func(*args, **kwargs)
#   7%|▋         | 47/670 [00:06<01:21,  7.67it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/717.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1387.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2057.bmp is a low contrast image
#   return func(*args, **kwargs)
#   7%|▋         | 48/670 [00:06<01:19,  7.83it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/718.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1388.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2058.bmp is a low contrast image
#   return func(*args, **kwargs)
#   7%|▋         | 49/670 [00:06<01:20,  7.67it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/719.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1389.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2059.bmp is a low contrast image
#   return func(*args, **kwargs)
#   7%|▋         | 50/670 [00:06<01:29,  6.89it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/720.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1390.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2060.bmp is a low contrast image
#   return func(*args, **kwargs)
#   8%|▊         | 51/670 [00:06<01:27,  7.06it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/721.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1391.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2061.bmp is a low contrast image
#   return func(*args, **kwargs)
#   8%|▊         | 52/670 [00:07<01:22,  7.45it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/722.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1392.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2062.bmp is a low contrast image
#   return func(*args, **kwargs)
#   8%|▊         | 53/670 [00:07<01:24,  7.30it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/723.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1393.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2063.bmp is a low contrast image
#   return func(*args, **kwargs)
#   8%|▊         | 54/670 [00:07<01:27,  7.04it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/54.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/724.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/1394.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2064.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/54.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/724.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/1394.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/image/2064.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/724.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1394.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2064.bmp is a low contrast image
#   return func(*args, **kwargs)
#   8%|▊         | 55/670 [00:07<01:22,  7.42it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/725.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1395.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2065.bmp is a low contrast image
#   return func(*args, **kwargs)
#   8%|▊         | 56/670 [00:07<01:22,  7.43it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/726.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1396.bmp is a low contrast image
#   return func(*args, **kwargs)
# ...
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1992.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2662.bmp is a low contrast image
#   return func(*args, **kwargs)
#  97%|█████████▋| 653/670 [01:34<00:02,  6.72it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1323.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1993.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2663.bmp is a low contrast image
#   return func(*args, **kwargs)
#  98%|█████████▊| 654/670 [01:34<00:02,  6.79it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1324.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1994.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2664.bmp is a low contrast image
#   return func(*args, **kwargs)
#  98%|█████████▊| 655/670 [01:34<00:02,  6.85it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/655.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1325.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1995.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2665.bmp is a low contrast image
#   return func(*args, **kwargs)
#  98%|█████████▊| 656/670 [01:34<00:01,  7.05it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1326.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1996.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2666.bmp is a low contrast image
#   return func(*args, **kwargs)
#  98%|█████████▊| 657/670 [01:35<00:01,  6.69it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1327.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1997.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2667.bmp is a low contrast image
#   return func(*args, **kwargs)
#  98%|█████████▊| 658/670 [01:35<00:01,  6.92it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1328.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1998.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2668.bmp is a low contrast image
#   return func(*args, **kwargs)
#  98%|█████████▊| 659/670 [01:35<00:01,  7.23it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1329.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1999.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2669.bmp is a low contrast image
#   return func(*args, **kwargs)
#  99%|█████████▊| 660/670 [01:35<00:01,  7.05it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1330.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2000.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2670.bmp is a low contrast image
#   return func(*args, **kwargs)
#  99%|█████████▊| 661/670 [01:35<00:01,  7.00it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1331.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2001.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2671.bmp is a low contrast image
#   return func(*args, **kwargs)
#  99%|█████████▉| 662/670 [01:35<00:01,  6.55it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1332.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2002.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2672.bmp is a low contrast image
#   return func(*args, **kwargs)
#  99%|█████████▉| 663/670 [01:35<00:01,  6.84it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1333.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2003.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2673.bmp is a low contrast image
#   return func(*args, **kwargs)
#  99%|█████████▉| 664/670 [01:36<00:00,  7.07it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1334.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2004.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2674.bmp is a low contrast image
#   return func(*args, **kwargs)
#  99%|█████████▉| 665/670 [01:36<00:00,  7.18it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1335.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2005.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2675.bmp is a low contrast image
#   return func(*args, **kwargs)
#  99%|█████████▉| 666/670 [01:36<00:00,  7.32it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1336.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2006.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2676.bmp is a low contrast image
#   return func(*args, **kwargs)
# 100%|█████████▉| 667/670 [01:36<00:00,  7.08it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1337.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2007.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2677.bmp is a low contrast image
#   return func(*args, **kwargs)
# 100%|█████████▉| 668/670 [01:36<00:00,  7.55it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1338.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2008.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2678.bmp is a low contrast image
#   return func(*args, **kwargs)
# 100%|█████████▉| 669/670 [01:36<00:00,  7.11it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/1339.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2009.bmp is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_y/mask/2679.bmp is a low contrast image
#   return func(*args, **kwargs)
# 100%|██████████| 670/670 [01:36<00:00,  6.91it/s]
#  43%|████▎     | 28/65 [00:01<00:01, 18.69it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2709.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2774.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2839.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2904.png is a low contrast image
#   return func(*args, **kwargs)
#  52%|█████▏    | 34/65 [00:01<00:01, 17.85it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2714.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2779.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2844.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2909.png is a low contrast image
#   return func(*args, **kwargs)
#  85%|████████▍ | 55/65 [00:02<00:00, 18.60it/s]c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2735.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2800.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2865.png is a low contrast image
#   return func(*args, **kwargs)
# c:\Users\mauri\Desktop\Facultad\Tesis\Pasantia\Tutorial Pytorch\tutoriales fing\.venv\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: data_z/image/2930.png is a low contrast image
#   return func(*args, **kwargs)
# 100%|██████████| 65/65 [00:03<00:00, 18.50it/s]
