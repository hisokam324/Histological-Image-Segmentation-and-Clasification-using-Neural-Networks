# %% [markdown]
# # Esto por ahora no usar porque es de clasificacion, no segmentacion

# %%
# !pip install medmnist
# Out:
# Collecting medmnist
#   Downloading medmnist-3.0.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from medmnist) (2.2.5)
# Collecting pandas (from medmnist)
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: scikit-learn in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from medmnist) (1.6.1)
# Requirement already satisfied: scikit-image in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from medmnist) (0.25.2)
# Requirement already satisfied: tqdm in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from medmnist) (4.67.1)
# Requirement already satisfied: Pillow in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from medmnist) (11.2.1)
# Collecting fire (from medmnist)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: torch in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from medmnist) (2.5.1+cu121)
# Requirement already satisfied: torchvision in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from medmnist) (0.20.1+cu121)
# Collecting termcolor (from fire->medmnist)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from pandas->medmnist) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->medmnist)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->medmnist)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->medmnist) (1.17.0)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from scikit-image->medmnist) (1.15.2)
# Requirement already satisfied: networkx>=3.0 in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from scikit-image->medmnist) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from scikit-image->medmnist) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from scikit-image->medmnist) (2025.3.30)
# Requirement already satisfied: packaging>=21 in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from scikit-image->medmnist) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from scikit-image->medmnist) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from scikit-learn->medmnist) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from scikit-learn->medmnist) (3.6.0)
# Requirement already satisfied: filelock in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from torch->medmnist) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from torch->medmnist) (4.13.2)
# Requirement already satisfied: jinja2 in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from torch->medmnist) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from torch->medmnist) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from torch->medmnist) (80.3.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from torch->medmnist) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from sympy==1.13.1->torch->medmnist) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from jinja2->torch->medmnist) (3.0.2)
# Requirement already satisfied: colorama in c:\users\mauri\desktop\facultad\tesis\pasantia\.venv\lib\site-packages (from tqdm->medmnist) (0.4.6)
# Downloading medmnist-3.0.2-py3-none-any.whl (25 kB)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: fire
#   Building wheel for fire (pyproject.toml): started
#   Building wheel for fire (pyproject.toml): finished with status 'done'
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114349 sha256=f2a64f0ba96e5c5a06da4a8ed211cc9ff2a4163a94b6974ed2d7232aca8a322b
#   Stored in directory: c:\users\mauri\appdata\local\pip\cache\wheels\9e\5b\45\29f72e55d87a29426b04b3cfdf20325c079eb97ab74f59017d
# Successfully built fire
# Installing collected packages: pytz, tzdata, termcolor, pandas, fire, medmnist
#
#    ---------------------------------------- 0/6 [pytz]
#    ---------------------------------------- 0/6 [pytz]
#    ------ --------------------------------- 1/6 [tzdata]
#    ------ --------------------------------- 1/6 [tzdata]
#    ------ --------------------------------- 1/6 [tzdata]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------------- ------------- 4/6 [fire]
#    -------------------------- ------------- 4/6 [fire]
#    -------------------------- ------------- 4/6 [fire]
#    --------------------------------- ------ 5/6 [medmnist]
#    ---------------------------------------- 6/6 [medmnist]
#
# Successfully installed fire-0.7.0 medmnist-3.0.2 pandas-2.2.3 pytz-2025.2 termcolor-3.1.0 tzdata-2025.2

# %%
from tqdm import tqdm
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torchvision.transforms as transforms


from medmnist import PathMNIST
#import medmnist
#from medmnist import INFO, Evaluator

# %%
train_dataset = PathMNIST(split="train", download=True)
# Out:
# Downloading https://zenodo.org/records/10519652/files/pathmnist.npz?download=1 to C:\Users\mauri\.medmnist\pathmnist.npz
# 100%|██████████| 206M/206M [14:46<00:00, 232kB/s]

# %%
print(len(train_dataset))
print(train_dataset[0])
# Out:
# 89996
# (<PIL.Image.Image image mode=RGB size=28x28 at 0x2241146ABA0>, array([0]))

# %%
#print(f"MedMNIST v{medmnist.__version__} @ {medmnist.HOMEPAGE}")

# %%
from medmnist import PathMNIST
dataset = PathMNIST(split='train', download=True, size=224)
